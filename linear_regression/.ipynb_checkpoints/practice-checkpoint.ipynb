# %% [markdown]
# ## Linear Regression
# - kaggle dummy data, preprocessing
# - sklearn
# - own implementation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load data, check null, fillna or dropna, visualization

# %%
# only one one data points has null in y value - drop
test = pd.read_csv('data/test.csv').dropna()
train = pd.read_csv('data/train.csv').dropna()

# %%
train['x'].max()
# Out:
# 100.0

# %%
train[train['x']==3530.15736917][['x','y']]
# Out:
# Empty DataFrame
# Columns: [x, y]
# Index: []

# %%
train['y'].max()
# Out:
# 108.8716183

# %%
test['x'].max()
# Out:
# 100

# %%
test['y'].max()
# Out:
# 105.5918375

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(train['x'], train['y'], label='data', linewidth=0.1, color='red')
ax.set_title('dummy data', fontsize=12, color='blue')
ax.legend(loc='best')
plt.show()

# %%
X_train = np.array(train['x']).reshape(-1,1).astype(int)
Y_train = np.array(train['y']).reshape(-1,1).astype(int)
X_test = np.array(test['x']).reshape(-1,1).astype(int)
Y_test = np.array(test['y']).reshape(-1,1).astype(int)

# %%
X_train
# Out:
# array([[ 0.01628068, -0.04464164, -0.04716281, ..., -0.03949338,
#          0.02736771,  0.02791705],
#        [ 0.0090156 , -0.04464164,  0.04552903, ..., -0.03949338,
#          0.04613233,  0.03620126],
#        [ 0.02717829, -0.04464164,  0.00672779, ...,  0.03430886,
#          0.04067226,  0.01134862],
#        ...,
#        [-0.0382074 , -0.04464164, -0.0105172 , ..., -0.00259226,
#         -0.01811827, -0.01764612],
#        [-0.01641217, -0.04464164, -0.05255187, ..., -0.03949338,
#         -0.06832974, -0.03007245],
#        [ 0.0090156 , -0.04464164, -0.02237314, ..., -0.07085934,
#         -0.06291295, -0.03835666]], dtype=float32)

# %%
X_train[:,0].max()
# Out:
# 100

# %%
Y_train[:,0].max()
# Out:
# 108

# %% [markdown]
# ### Using Scikilearn

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(X_train, Y_train, color='orange', linewidth=0.05, label='observed')
ax.plot(X_train, regressor.predict(X_train), color='tab:red', linewidth=1, label='regressor')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()

# %%
def obtain_matrix(reg, Y_train, X_train, Y_test, X_test):
    
    print('coef is {}'.format(reg.coef_[0][0]))
    print('intercept is {}'.format(reg.intercept_[0]))
    print('r2 is {}'.format(sklearn.metrics.r2_score(Y_train, regressor.predict(X_train))))
    print('mse is {}'.format(sklearn.metrics.r2_score(Y_test, regressor.predict(X_test))))
    
    return

# %%
# There is no correct value for MSE. Simply put, the lower the value the better and 
# 0 means the model is perfect. Since there is no correct answer, 
# the MSE's basic value is in selecting one prediction model over another.
obtain_matrix(regressor, Y_train, X_train, Y_test, X_test)
# Out:
# coef is 1.0004468112612355
# intercept is -0.5688419480583562
# r2 is 0.9907754943708471
# mse is 0.9886850442199884

# %% [markdown]
# #### Prediction

# %%
regressor.predict(X_test)
# Out:
# array([[76.46556252],
#        [20.44054109],
#        [21.4409879 ],
#        [19.44009428],
#        [35.44724326],
#        [14.43786022],
#        [61.45886035],
#        [94.47360512],
#        [19.44009428],
#        [ 4.43339211],
#        [ 3.4329453 ],
#        [18.43964747],
# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(X_test, Y_test, color='orange', linewidth=0.05, label='x_observed')
ax.plot(X_test, regressor.predict(X_test), color='tab:red', linewidth=1, label='x_prediction')
ax.set_xlabel('x_test')
ax.set_ylabel('y')
ax.legend()

# %% [markdown]
# ### Using statsmodel

# %%
X_train
# Out:
# array([[ 1., 24.],
#        [ 1., 50.],
#        [ 1., 15.],
#        ...,
#        [ 1., 82.],
#        [ 1., 66.],
#        [ 1., 97.]])

# %%
X_test
# Out:
# array([[ 77],
#        [ 21],
#        [ 22],
#        [ 20],
#        [ 36],
#        [ 15],
#        [ 62],
#        [ 95],
#        [ 20],
#        [  5],
#        [  4],
#        [ 19],
#        [ 96],
#        [ 62],
#        [ 36],
#        [ 15],
#        [ 65],
#        [ 14],
#        [ 87],
#        [ 69],
#        [ 89],
#        [ 51],
#        [ 89],
#        [ 27],
#        [ 97],
#        [ 58],
#        [ 79],
#        [ 21],
#        [ 93],
#        [ 27],
#        [ 99],
#        [ 31],
#        [ 33],
#        [ 80],
#        [ 28],
#        [ 47],
#        [ 53],
#        [ 69],
#        [ 28],
#        [ 33],
#        [ 91],
#        [ 71],
#        [ 50],
#        [ 76],
#        [  4],
#        [ 37],
#        [ 70],
#        [ 68],
#        [ 40],
#        [ 35],
#        [ 94],
#        [ 88],
#        [ 52],
#        [ 31],
#        [ 59],
#        [  0],
#        [ 39],
#        [ 64],
#        [ 69],
#        [ 57],
#        [ 13],
#        [ 72],
#        [ 76],
#        [ 61],
#        [ 82],
#        [ 18],
#        [ 41],
#        [ 50],
#        [ 55],
#        [ 13],
#        [ 46],
#        [ 13],
#        [ 79],
#        [ 53],
#        [ 15],
#        [ 28],
#        [ 81],
#        [ 69],
#        [ 52],
#        [ 84],
#        [ 68],
#        [ 27],
#        [ 56],
#        [ 48],
#        [ 40],
#        [ 39],
#        [ 82],
#        [100],
#        [ 59],
#        [ 43],
#        [ 67],
#        [ 38],
#        [ 63],
#        [ 91],
#        [ 60],
#        [ 14],
#        [ 21],
#        [ 87],
#        [ 73],
#        [ 32],
#        [  2],
#        [ 82],
#        [ 19],
#        [ 74],
#        [ 42],
#        [ 12],
#        [  1],
#        [ 90],
#        [ 89],
#        [  0],
#        [ 41],
#        [ 16],
#        [ 94],
#        [ 97],
#        [ 66],
#        [ 24],
#        [ 17],
#        [ 90],
#        [ 13],
#        [  0],
#        [ 64],
#        [ 96],
#        [ 98],
#        [ 12],
#        [ 41],
#        [ 47],
#        [ 78],
#        [ 20],
#        [ 89],
#        [ 29],
#        [ 64],
#        [ 75],
#        [ 12],
#        [ 25],
#        [ 28],
#        [ 30],
#        [ 65],
#        [ 59],
#        [ 64],
#        [ 53],
#        [ 71],
#        [ 97],
#        [ 73],
#        [  9],
#        [ 12],
#        [ 63],
#        [ 99],
#        [ 60],
#        [ 35],
#        [  2],
#        [ 60],
#        [ 32],
#        [ 94],
#        [ 84],
#        [ 63],
#        [ 22],
#        [ 81],
#        [ 93],
#        [ 33],
#        [  7],
#        [ 42],
#        [ 46],
#        [ 54],
#        [ 16],
#        [ 49],
#        [ 43],
#        [ 95],
#        [ 66],
#        [ 21],
#        [ 35],
#        [ 80],
#        [ 37],
#        [ 54],
#        [ 56],
#        [  1],
#        [ 32],
#        [ 58],
#        [ 32],
#        [ 46],
#        [ 72],
#        [ 17],
#        [ 97],
#        [ 93],
#        [ 91],
#        [ 37],
#        [  4],
#        [ 54],
#        [ 51],
#        [ 27],
#        [ 46],
#        [ 92],
#        [ 73],
#        [ 77],
#        [ 91],
#        [ 61],
#        [ 99],
#        [  4],
#        [ 72],
#        [ 19],
#        [ 57],
#        [ 78],
#        [ 26],
#        [ 74],
#        [ 90],
#        [ 66],
#        [ 13],
#        [ 40],
#        [ 77],
#        [ 67],
#        [ 75],
#        [ 23],
#        [ 45],
#        [ 59],
#        [ 44],
#        [ 23],
#        [ 55],
#        [ 55],
#        [ 95],
#        [ 12],
#        [  4],
#        [  7],
#        [100],
#        [ 48],
#        [ 42],
#        [ 96],
#        [ 39],
#        [100],
#        [ 87],
#        [ 14],
#        [ 14],
#        [ 37],
#        [  5],
#        [ 88],
#        [ 91],
#        [ 65],
#        [ 74],
#        [ 56],
#        [ 16],
#        [  5],
#        [ 28],
#        [ 92],
#        [ 46],
#        [ 54],
#        [ 39],
#        [ 44],
#        [ 31],
#        [ 68],
#        [ 86],
#        [ 90],
#        [ 38],
#        [ 21],
#        [ 95],
#        [ 56],
#        [ 60],
#        [ 65],
#        [ 78],
#        [ 89],
#        [  6],
#        [ 67],
#        [ 36],
#        [ 16],
#        [100],
#        [ 45],
#        [ 73],
#        [ 57],
#        [ 20],
#        [ 76],
#        [ 34],
#        [ 55],
#        [ 72],
#        [ 55],
#        [  8],
#        [ 56],
#        [ 72],
#        [ 58],
#        [  6],
#        [ 96],
#        [ 23],
#        [ 58],
#        [ 23],
#        [ 19],
#        [ 25],
#        [ 64],
#        [ 21],
#        [ 59],
#        [ 19],
#        [ 16],
#        [ 42],
#        [ 43],
#        [ 61],
#        [ 92],
#        [ 11],
#        [ 41],
#        [  1],
#        [  8],
#        [ 71],
#        [ 46],
#        [ 55],
#        [ 62],
#        [ 47]])

# %%
import statsmodels.api as sm

# %%
X_train_ = sm.add_constant(X_train)

# An intercept is not included by default and should be 
# added by the user. See statsmodels.tools.add_constant.
X_test_ = sm.add_constant(X_test) 
model = sm.OLS(Y_train, X_train_).fit()
prediction = model.predict(X_test_)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 7.486e+04
# Date:                Thu, 06 Aug 2020   Prob (F-statistic):               0.00
# Time:                        06:12:46   Log-Likelihood:                -1709.8
# No. Observations:                 699   AIC:                             3424.
# Df Residuals:                     697   BIC:                             3433.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5688      0.211     -2.692      0.007      -0.984      -0.154
# x1             1.0004      0.004    273.610      0.000       0.993       1.008
# ==============================================================================
# Omnibus:                        0.158   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.924   Jarque-Bera (JB):                0.222
# Skew:                           0.030   Prob(JB):                        0.895
# Kurtosis:                       2.937   Cond. No.                         115.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def one_ax(figsize, style_list, X_train, Y):
    
    fig,ax = plt.subplots(figsize=figsize)
# Out:
# array([[  1.,  77.],
#        [  1.,  21.],
#        [  1.,  22.],
#        [  1.,  20.],
#        [  1.,  36.],
#        [  1.,  15.],
#        [  1.,  62.],
#        [  1.,  95.],
#        [  1.,  20.],
#        [  1.,   5.],
#        [  1.,   4.],
#        [  1.,  19.],
#        [  1.,  96.],
#        [  1.,  62.],
#        [  1.,  36.],
#        [  1.,  15.],
#        [  1.,  65.],
#        [  1.,  14.],
#        [  1.,  87.],
#        [  1.,  69.],
#        [  1.,  89.],
#        [  1.,  51.],
#        [  1.,  89.],
#        [  1.,  27.],
#        [  1.,  97.],
#        [  1.,  58.],
#        [  1.,  79.],
#        [  1.,  21.],
#        [  1.,  93.],
#        [  1.,  27.],
#        [  1.,  99.],
#        [  1.,  31.],
#        [  1.,  33.],
#        [  1.,  80.],
#        [  1.,  28.],
#        [  1.,  47.],
#        [  1.,  53.],
#        [  1.,  69.],
#        [  1.,  28.],
#        [  1.,  33.],
#        [  1.,  91.],
#        [  1.,  71.],
#        [  1.,  50.],
#        [  1.,  76.],
#        [  1.,   4.],
#        [  1.,  37.],
#        [  1.,  70.],
#        [  1.,  68.],
#        [  1.,  40.],
#        [  1.,  35.],
#        [  1.,  94.],
#        [  1.,  88.],
#        [  1.,  52.],
#        [  1.,  31.],
#        [  1.,  59.],
#        [  1.,   0.],
#        [  1.,  39.],
#        [  1.,  64.],
#        [  1.,  69.],
#        [  1.,  57.],
#        [  1.,  13.],
#        [  1.,  72.],
#        [  1.,  76.],
#        [  1.,  61.],
#        [  1.,  82.],
#        [  1.,  18.],
#        [  1.,  41.],
#        [  1.,  50.],
#        [  1.,  55.],
#        [  1.,  13.],
#        [  1.,  46.],
#        [  1.,  13.],
#        [  1.,  79.],
#        [  1.,  53.],
#        [  1.,  15.],
#        [  1.,  28.],
#        [  1.,  81.],
#        [  1.,  69.],
#        [  1.,  52.],
#        [  1.,  84.],
#        [  1.,  68.],
#        [  1.,  27.],
#        [  1.,  56.],
#        [  1.,  48.],
#        [  1.,  40.],
#        [  1.,  39.],
#        [  1.,  82.],
#        [  1., 100.],
#        [  1.,  59.],
#        [  1.,  43.],
#        [  1.,  67.],
#        [  1.,  38.],
#        [  1.,  63.],
#        [  1.,  91.],
#        [  1.,  60.],
#        [  1.,  14.],
#        [  1.,  21.],
#        [  1.,  87.],
#        [  1.,  73.],
#        [  1.,  32.],
#        [  1.,   2.],
#        [  1.,  82.],
#        [  1.,  19.],
#        [  1.,  74.],
#        [  1.,  42.],
#        [  1.,  12.],
#        [  1.,   1.],
#        [  1.,  90.],
#        [  1.,  89.],
#        [  1.,   0.],
#        [  1.,  41.],
#        [  1.,  16.],
#        [  1.,  94.],
#        [  1.,  97.],
#        [  1.,  66.],
#        [  1.,  24.],
#        [  1.,  17.],
#        [  1.,  90.],
#        [  1.,  13.],
#        [  1.,   0.],
#        [  1.,  64.],
#        [  1.,  96.],
#        [  1.,  98.],
#        [  1.,  12.],
#        [  1.,  41.],
#        [  1.,  47.],
#        [  1.,  78.],
#        [  1.,  20.],
#        [  1.,  89.],
#        [  1.,  29.],
#        [  1.,  64.],
#        [  1.,  75.],
#        [  1.,  12.],
#        [  1.,  25.],
#        [  1.,  28.],
#        [  1.,  30.],
#        [  1.,  65.],
#        [  1.,  59.],
#        [  1.,  64.],
#        [  1.,  53.],
#        [  1.,  71.],
#        [  1.,  97.],
#        [  1.,  73.],
#        [  1.,   9.],
#        [  1.,  12.],
#        [  1.,  63.],
#        [  1.,  99.],
#        [  1.,  60.],
#        [  1.,  35.],
#        [  1.,   2.],
#        [  1.,  60.],
#        [  1.,  32.],
#        [  1.,  94.],
#        [  1.,  84.],
#        [  1.,  63.],
#        [  1.,  22.],
#        [  1.,  81.],
#        [  1.,  93.],
#        [  1.,  33.],
#        [  1.,   7.],
#        [  1.,  42.],
#        [  1.,  46.],
#        [  1.,  54.],
#        [  1.,  16.],
#        [  1.,  49.],
#        [  1.,  43.],
#        [  1.,  95.],
#        [  1.,  66.],
#        [  1.,  21.],
#        [  1.,  35.],
#        [  1.,  80.],
#        [  1.,  37.],
#        [  1.,  54.],
#        [  1.,  56.],
#        [  1.,   1.],
#        [  1.,  32.],
#        [  1.,  58.],
#        [  1.,  32.],
#        [  1.,  46.],
#        [  1.,  72.],
#        [  1.,  17.],
#        [  1.,  97.],
#        [  1.,  93.],
#        [  1.,  91.],
#        [  1.,  37.],
#        [  1.,   4.],
#        [  1.,  54.],
#        [  1.,  51.],
#        [  1.,  27.],
#        [  1.,  46.],
#        [  1.,  92.],
#        [  1.,  73.],
#        [  1.,  77.],
#        [  1.,  91.],
#        [  1.,  61.],
#        [  1.,  99.],
#        [  1.,   4.],
#        [  1.,  72.],
#        [  1.,  19.],
#        [  1.,  57.],
#        [  1.,  78.],
#        [  1.,  26.],
#        [  1.,  74.],
#        [  1.,  90.],
#        [  1.,  66.],
#        [  1.,  13.],
#        [  1.,  40.],
#        [  1.,  77.],
#        [  1.,  67.],
#        [  1.,  75.],
#        [  1.,  23.],
#        [  1.,  45.],
#        [  1.,  59.],
#        [  1.,  44.],
#        [  1.,  23.],
#        [  1.,  55.],
#        [  1.,  55.],
#        [  1.,  95.],
#        [  1.,  12.],
#        [  1.,   4.],
#        [  1.,   7.],
#        [  1., 100.],
#        [  1.,  48.],
#        [  1.,  42.],
#        [  1.,  96.],
#        [  1.,  39.],
#        [  1., 100.],
#        [  1.,  87.],
#        [  1.,  14.],
#        [  1.,  14.],
#        [  1.,  37.],
#        [  1.,   5.],
#        [  1.,  88.],
#        [  1.,  91.],
#        [  1.,  65.],
#        [  1.,  74.],
#        [  1.,  56.],
#        [  1.,  16.],
#        [  1.,   5.],
#        [  1.,  28.],
#        [  1.,  92.],
#        [  1.,  46.],
#        [  1.,  54.],
#        [  1.,  39.],
#        [  1.,  44.],
#        [  1.,  31.],
#        [  1.,  68.],
#        [  1.,  86.],
#        [  1.,  90.],
#        [  1.,  38.],
#        [  1.,  21.],
#        [  1.,  95.],
#        [  1.,  56.],
#        [  1.,  60.],
#        [  1.,  65.],
#        [  1.,  78.],
#        [  1.,  89.],
#        [  1.,   6.],
#        [  1.,  67.],
#        [  1.,  36.],
#        [  1.,  16.],
#        [  1., 100.],
#        [  1.,  45.],
#        [  1.,  73.],
#        [  1.,  57.],
#        [  1.,  20.],
#        [  1.,  76.],
#        [  1.,  34.],
#        [  1.,  55.],
#        [  1.,  72.],
#        [  1.,  55.],
#        [  1.,   8.],
#        [  1.,  56.],
#        [  1.,  72.],
#        [  1.,  58.],
#        [  1.,   6.],
#        [  1.,  96.],
#        [  1.,  23.],
#        [  1.,  58.],
#        [  1.,  23.],
#        [  1.,  19.],
#        [  1.,  25.],
#        [  1.,  64.],
#        [  1.,  21.],
#        [  1.,  59.],
#        [  1.,  19.],
#        [  1.,  16.],
#        [  1.,  42.],
#        [  1.,  43.],
#        [  1.,  61.],
#        [  1.,  92.],
#        [  1.,  11.],
#        [  1.,  41.],
#        [  1.,   1.],
#        [  1.,   8.],
#        [  1.,  71.],
#        [  1.,  46.],
#        [  1.,  55.],
#        [  1.,  62.],
#        [  1.,  47.]])

# %%
fig,ax = plt.subplots(figsize=(10,10))
ax.scatter(X_test, Y_test, label='test_observed', color='green')
ax.plot(X_test, model.predict(X_test_), label='test_predicted', color='black')
ax.set_title('observed vs predictions')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()

# %% [markdown]
# ### My own implementation of linear model

# %%
class linear_model():
    
    def __init__(self):
        
        pass
    
    def initialise_params(self, num_dim):
        
        w = np.zeros((num_dim, 1))
        b = 0
        
        return w, b 
        
    def loss(self, X, y, w, b):
        
        num_train = X.shape[0]
#         num_features = X.shape[1]
        
        y_hat = np.dot(X, w) + b
        
        loss = np.sum((y_hat - y) ** 2) / num_train
        dw = np.dot(X.T, (y_hat - y)) / num_train
        db = np.sum((y_hat, y)) / num_train
        
        return y_hat, loss, dw, db
    
    def train(self, X, y, learning_rate, num_epoch):
        
        w, b = self.initialise_params(X.shape[1])
        loss_list = []
        
        for i in range(1, num_epoch):
            y_hat, loss, dw, db = self.loss(X, y, w, b)
            
            loss_list.append(loss)
            
            w += -learning_rate * dw
            b += -learning_rate * db
            
            if i % 1000 == 0:
                print('epoch {} loss {}'.format(i, loss))
                
            params = {
                'w': w,
                'b': b
            }
            
            gradients = {
                'dw': dw,
                'db': db
            }
            
        return loss_list, loss, params, gradients
    
    def predict(self, X, params):
        
        w = params['w']
        b = params['b']
        
        return np.dot(X, w) + b

# %% [markdown]
# #### using dummy dataset

# %%
X_train
# Out:
# array([[ 24],
#        [ 50],
#        [ 15],
#        [ 38],
#        [ 87],
#        [ 36],
#        [ 12],
#        [ 81],
#        [ 25],
#        [  5],
#        [ 16],
#        [ 16],
#        [ 24],
#        [ 39],
#        [ 54],
#        [ 60],
#        [ 26],
#        [ 73],
#        [ 29],
#        [ 31],
#        [ 68],
#        [ 87],
#        [ 58],
#        [ 54],
#        [ 84],
#        [ 58],
#        [ 49],
#        [ 20],
#        [ 19],
#        [ 82],
#        [ 63],
#        [ 11],
#        [ 60],
#        [ 72],
#        [ 11],
#        [100],
#        [ 45],
#        [ 14],
#        [ 48],
#        [ 42],
#        [ 52],
#        [ 36],
#        [ 28],
#        [ 62],
#        [ 95],
#        [ 66],
#        [ 99],
#        [ 46],
#        [ 89],
#        [ 69],
#        [ 12],
#        [ 78],
#        [ 71],
#        [ 81],
#        [ 58],
#        [ 94],
#        [ 88],
#        [ 63],
#        [ 94]])

# %%
X_train.shape
# Out:
# (699, 1)

# %%
Y_train.shape
# Out:
# (699, 1)

# %%
lm = linear_model()
loss_list, loss, params, gradients = lm.train(X_train, Y_train, 0.001, 100000)
# Out:
# /Users/victor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: overflow encountered in square
# epoch 1000 loss nan
# epoch 2000 loss nan
# epoch 3000 loss nan
# epoch 4000 loss nan
# epoch 5000 loss nan
# epoch 6000 loss nan
# epoch 7000 loss nan
# epoch 8000 loss nan
# epoch 9000 loss nan
# epoch 10000 loss nan
# epoch 11000 loss nan
# epoch 12000 loss nan
# epoch 13000 loss nan
# epoch 14000 loss nan
# epoch 15000 loss nan
# epoch 16000 loss nan
# epoch 17000 loss nan
# epoch 18000 loss nan
# epoch 19000 loss nan
# epoch 20000 loss nan
# epoch 21000 loss nan
# epoch 22000 loss nan
# epoch 23000 loss nan
# epoch 24000 loss nan
# epoch 25000 loss nan
# epoch 26000 loss nan
# epoch 27000 loss nan
# epoch 28000 loss nan
# epoch 29000 loss nan
# epoch 30000 loss nan
# epoch 31000 loss nan
# epoch 32000 loss nan
# epoch 33000 loss nan
# epoch 34000 loss nan
# epoch 35000 loss nan
# epoch 36000 loss nan
# epoch 37000 loss nan
# epoch 38000 loss nan
# epoch 39000 loss nan
# epoch 40000 loss nan
# epoch 41000 loss nan
# epoch 42000 loss nan
# epoch 43000 loss nan
# epoch 44000 loss nan
# epoch 45000 loss nan
# epoch 46000 loss nan
# epoch 47000 loss nan
# epoch 48000 loss nan
# epoch 49000 loss nan
# epoch 50000 loss nan
# epoch 51000 loss nan
# epoch 52000 loss nan
# epoch 53000 loss nan
# epoch 54000 loss nan
# epoch 55000 loss nan
# epoch 56000 loss nan
# epoch 57000 loss nan
# epoch 58000 loss nan
# epoch 59000 loss nan
# epoch 60000 loss nan
# epoch 61000 loss nan
# epoch 62000 loss nan
# epoch 63000 loss nan
# epoch 64000 loss nan
# epoch 65000 loss nan
# epoch 66000 loss nan
# epoch 67000 loss nan
# epoch 68000 loss nan
# epoch 69000 loss nan
# epoch 70000 loss nan
# epoch 71000 loss nan
# epoch 72000 loss nan
# epoch 73000 loss nan
# epoch 74000 loss nan
# epoch 75000 loss nan
# epoch 76000 loss nan
# epoch 77000 loss nan
# epoch 78000 loss nan
# epoch 79000 loss nan
# epoch 80000 loss nan
# epoch 81000 loss nan
# epoch 82000 loss nan
# epoch 83000 loss nan
# epoch 84000 loss nan
# epoch 85000 loss nan
# epoch 86000 loss nan
# epoch 87000 loss nan
# epoch 88000 loss nan
# epoch 89000 loss nan
# epoch 90000 loss nan
# epoch 91000 loss nan
# epoch 92000 loss nan
# epoch 93000 loss nan
# epoch 94000 loss nan
# epoch 95000 loss nan
# epoch 96000 loss nan
# epoch 97000 loss nan
# epoch 98000 loss nan
# epoch 99000 loss nan

# %%
prediction = lm.predict(X_test, params)

# %%
X_test.shape
# Out:
# (300, 1)

# %%
y_test.shape
# Out:
# (45, 1)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(X_test[:,0], y_test[:,0], label='observed')
ax.plot(X_test[:,0], prediction[:,0], label='predicted')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-ba2d28a208b9> in <module>
#       1 fig, ax = plt.subplots(figsize=(10,10))
# ----> 2 ax.scatter(X_test[:,0], y_test[:,0], label='observed')
#       3 ax.plot(X_test[:,0], prediction[:,0], label='predicted')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4180         y = np.ma.ravel(y)
#    4181         if x.size != y.size:
# -> 4182             raise ValueError("x and y must be the same size")
#    4183
#    4184         if s is None:
#
# ValueError: x and y must be the same size

# %% [markdown]
# ##### using sklearn diabetes dataset

# %%
from sklearn.datasets import load_diabetes
from sklearn.utils import shuffle

diabetes = load_diabetes()
data = diabetes.data
target = diabetes.target

data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
X, y = shuffle(data, target, random_state=10)
X = X.astype(np.float32)
X
# Out:
# array([[ 0.01628068, -0.04464164, -0.04716281, ..., -0.03949338,
#          0.02736771,  0.02791705],
#        [ 0.0090156 , -0.04464164,  0.04552903, ..., -0.03949338,
#          0.04613233,  0.03620126],
#        [ 0.02717829, -0.04464164,  0.00672779, ...,  0.03430886,
#          0.04067226,  0.01134862],
#        ...,
#        [-0.05273756,  0.05068012, -0.01806189, ...,  0.1081111 ,
#          0.03605579, -0.04249877],
#        [-0.00551456,  0.05068012, -0.00836158, ..., -0.00259226,
#          0.08058546,  0.00720652],
#        [-0.03457486,  0.05068012, -0.02560657, ..., -0.01550765,
#          0.01482271,  0.04034337]], dtype=float32)

# %%
X[:1,:1]
# Out:
# array([[0.01628068]], dtype=float32)

# %%
X[0][1]
# Out:
# -0.044641636

# %%
# split train/test 
offset = int(X.shape[0] * 0.9)
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

print('X_train shape is {}'.format(X_train.shape))
print('X_test shape is {}'.format(X_test.shape))
print('y_train shape is {}'.format(y_train.shape))
print('y_test shape is {}'.format(y_test.shape))
# Out:
# X_train shape is (397, 10)
# X_test shape is (45, 10)
# y_train shape is (397, 1)
# y_test shape is (45, 1)

# %%
loss_list, loss, params, gradients = linear_model().train(X_train, y_train, 0.001, 100000)
# Out:
# epoch 1000 loss 68150.25887136244
# epoch 2000 loss 87103.42317201186
# epoch 3000 loss 94685.57103477133
# epoch 4000 loss 97537.3100402004
# epoch 5000 loss 98575.71804439405
# epoch 6000 loss 98937.64783972141
# epoch 7000 loss 99049.79566092508
# epoch 8000 loss 99070.22415594794
# epoch 9000 loss 99057.20557897288
# epoch 10000 loss 99032.18274324333
# epoch 90000 loss 97488.2432401025
# epoch 91000 loss 97477.33782608047
# epoch 92000 loss 97466.5637951185
# epoch 93000 loss 97455.9192246991
# epoch 94000 loss 97445.40222374052
# epoch 95000 loss 97435.0109320552
# epoch 96000 loss 97424.74351981886
# epoch 97000 loss 97414.5981870468
# epoch 98000 loss 97404.5731630815
# epoch 99000 loss 97394.66670608739

# %%
print(params)
# Out:
# {'w': array([[ 52.7345521 ],
#        [ 12.62817846],
#        [161.55400294],
#        [149.22615339],
#        [ 12.31368618],
#        [  2.42202886],
#        [-96.59714785],
#        [ 66.48493542],
#        [126.5688651 ],
#        [ 70.26861439]]), 'b': -152.44228509848705}

# %%
y_predict = linear_model().predict(X_test, params)
y_predict[:5]
# Out:
# array([[-121.5468141 ],
#        [-196.11989805],
#        [ -93.37772254],
#        [-140.42851369],
#        [-177.0005478 ]])

# %%
X_test[:,0]
# Out:
# array([ 0.05987114, -0.02367725,  0.09619652,  0.04170844, -0.04547248,
#        -0.01277963, -0.0382074 ,  0.0562386 ,  0.03081083, -0.02730979,
#         0.04897352,  0.01628068,  0.00538306, -0.09632801,  0.03807591,
#        -0.02367725,  0.04897352,  0.00175052,  0.0562386 ,  0.03081083,
#        -0.02730979,  0.04897352, -0.04910501, -0.10722563, -0.04910501,
#        -0.06000263,  0.02354575, -0.00551456, -0.00551456,  0.05260606,
#         0.02354575,  0.00538306, -0.04910501,  0.01264814,  0.04170844,
#         0.04170844, -0.05273756, -0.04547248, -0.01641217,  0.00538306,
#        -0.00914709, -0.02367725, -0.05273756, -0.00551456, -0.03457486],
#       dtype=float32)

# %%
y_test[:,0]
# Out:
# array([153., 184., 124.,  49., 200., 245., 151., 200.,  51., 168., 107.,
#        332.,  68., 147., 270.,  89.,  69., 261., 265., 178.,  75.,  42.,
#        281., 233., 126., 275.,  53.,  89., 114., 199., 135., 132.,  53.,
#         99.,  64., 209.,  67.,  71., 187., 272., 220., 166.,  85., 237.,
#        214.])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))

ax.scatter(X_test[:,0], y_test[:,0], label='observed')
ax.plot(X_test[:,0], y_predict[:,0], label='predicted')

# %%
plt.plot(loss_list)
plt.show()

# %%
c = np.zeros((5,1))
c.shape[1]
# Out:
# 1

# %%
def cost_fun(a, b, x, y):
    
    size = len(x)
    
    y_hat = linear_model(a, b, x)
    sse = (1/(2*size)) * np.square(y_hat - y).sum()
    
    return sse  

error = cost_fun(1, 2, [[1],[1],[2]], [[-1],[3],[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-15a71f454249> in <module>
#       8     return sse
#       9
# ---> 10 error = cost_fun(1, 2, [[1],[1],[2]], [[-1],[3],[1]])
#
# <ipython-input-61-15a71f454249> in cost_fun(a, b, x, y)
#       3     size = len(x)
#       4
# ----> 5     y_hat = linear_model(a, b, x)
#       6     sse = (1/(2*size)) * np.square(y_hat - y).sum()
#       7
#
# <ipython-input-60-1451952d17bb> in linear_model(a, b, x)
#       1 def linear_model(a, b, x):
#       2
# ----> 3     return [a*x + b]
#
# TypeError: can only concatenate list (not "int") to list
